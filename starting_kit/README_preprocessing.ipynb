# %% [markdown]
# <div style="background:#FFFFAA">
# <img src="logo.jpg", width=150, ALIGN="left", border=20>
#     <h1>Team GAIASAVERS</h1>
#     <h3>Alban Petit, Wafa Bouzouita,Timothée Babinet, Maxime Chor, Eric Wang, Sebastien Warichet</h3>
#     <h2>Plankton classification challenge</h2>
#
# <br>This code was tested with <br>
# Python 3.7 |Anaconda custom (64-bit)| (default, Jun 28 2018, 11:07:29) (https://anaconda.org/)<br>
# <i> Adapted for Chalab by Isabelle Guyon from original code of Balázs Kégl</i> <br>
# <a href="http://www.datascience-paris-saclay.fr">Paris Saclay Center for Data Science (CDS)</a>
# </center>
# <p>
# ALL INFORMATION, SOFTWARE, DOCUMENTATION, AND DATA ARE PROVIDED "AS-IS". The CDS, CHALEARN, AND/OR OTHER ORGANIZERS OR CODE AUTHORS DISCLAIM ANY EXPRESSED OR IMPLIED WARRANTIES, INCLUDING, BUT NOT LIMITED TO, THE IMPLIED WARRANTIES OF MERCHANTABILITY AND FITNESS FOR ANY PARTICULAR PURPOSE, AND THE WARRANTY OF NON-INFRIGEMENT OF ANY THIRD PARTY'S INTELLECTUAL PROPERTY RIGHTS. IN NO EVENT SHALL AUTHORS AND ORGANIZERS BE LIABLE FOR ANY SPECIAL,
# INDIRECT OR CONSEQUENTIAL DAMAGES OR ANY DAMAGES WHATSOEVER ARISING OUT OF OR IN CONNECTION WITH THE USE OR PERFORMANCE OF SOFTWARE, DOCUMENTS, MATERIALS, PUBLICATIONS, OR INFORMATION MADE AVAILABLE FOR THE CHALLENGE.
# </div>

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Introduction </h2>
#      <br>
#
# According to [NRMA15], a link has been found between the quality of water and the presence of plankton in said water. As water quality increases, the abundance and diversity of plankton does as well. The aim of our project is to build a plankton classifier to assess water quality.
#
# We use for this problem the Bering Sea dataset, an in situ plankton dataset published in May 2019 by Kaichang Cheng [Che19]. This datset contains 7 classes with an even spread.
#
#
# References and credits:
# - [NRMA15] A. Nair, J.K. Reshma, A. Mathew, and A. Ashok. Effect of water quality on phytoplankton abundance in selected ponds of nedumangad block panchayat, kerala. Emer Life Sci Res, 2015.
# - [Che19] K. Cheng. Bering sea dataset. https://doi.org/10.6084/m9.figshare.8146283.v3, 2019.
#  <br>
# </div>

# %% [markdown]
# <img src="images/sample.png" alt="Drawing"/>
# To see more images for each class, see the "images" folder.

# %%
model_dir = 'sample_code_submission/'                        # Change the model to a better one once you have one!
result_dir = 'sample_result_submission/' 
problem_dir = 'ingestion_program/'  
score_dir = 'scoring_program/'
from sys import path; path.append(model_dir); path.append(problem_dir); path.append(score_dir); 
# %matplotlib inline
# Uncomment the next lines to auto-reload libraries (this causes some problem with pickles in Python 3)
# %load_ext autoreload
# %autoreload 2
import seaborn as sns; sns.set()
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h1> Step 1: Exploratory data analysis </h1>
# <p>
# We provide sample_data with the starting kit, but to prepare your submission, you must fetch the public_data from the challenge website and point to it.
#     <br>
#     <span style="color:red"> Just change the data name in the block below. In the rest of the section, replace the sample plots by anything you want. </span>
# </div>

# %%
data_dir = 'public_data'              # Change this to the directory where you put the input data
#data_dir = '../public_data'          # The sample_data directory should contain only a very small subset of the data
data_name = 'plankton'
# !ls $data_dir*
# Out:
# public_data.zip
#
# public_data:
# plankton_feat.name      plankton_test.data      plankton_valid.data
# plankton_label.name     plankton_train.data
# plankton_public.info    plankton_train.solution

# %% [markdown]
# <h3>Two "feature representation"</h3>
#
# <p>
# 1.
# All of the images are in various shades of gray. As such, we can represent every image by a vector of 90000 (300x300) features where each feature is a float value between 0 and 255 representing the brightness of a pixel (0 being a black pixel and 255 a white one). It is also possible to reduce the size of the images to reduce the number of features as seen in figure 3 where we reduced the size to 100x100 pixels.
# </p>

# %% [markdown]
# <tr>
#     <td> <img src="images/gray.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="images/binarized.png" alt="Drawing" style="width: 250px;"/> </td>
# </tr>

# %% [markdown]
# <p>
# 2. At first we will have four types of "features". Two "features" are applied on the binarized images.
#     <ul>
#         <li>The first is a sum of black pixels, per line and per column.
# This gives us 2 vectors of size 100. These "features" are representative among others of the shape of the plankton.
# For round seeders the ratio between rows and columns near the center of the image should be close.
# For longer plankton the ratio will be either low or high, depending on plankton position.
#         </li>
#         <li>The second is the average of the pixels.
#             This gives us information on the size of the plankton.
#         </li>
#         <li>The third feature is the variance and is applied to non-binarized images.</li>
#         <li>The last feature is the length of the contour of the plankton. It is obtained by applying a sobel filter on the image. This filter will put black pixels on the contours and white ones everywhere else. We can then just compute the amount of black pixels.
#     </ul>
# </p>

# %% [markdown]
# For convenience, we load the data as a "pandas" data frame, so we can use "pandas" and "seaborn" built in functions to explore the data.

# %%
from data_io import read_as_df
data = read_as_df(data_dir  + '/' + data_name)                # The data are loaded as a Pandas Data Frame
# Out:
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7

# %% [markdown]
# This shows the distribution of labels in the training set

# %%
data['target'].value_counts()
# Out:
# euphausiids     1536
# copepoda        1536
# medusae         1536
# fish_larvae     1536
# limacina        1536
# chaetognatha    1536
# other           1536
# Name: target, dtype: int64

# %% [markdown]
# The first rows of the dataset.

# %%
data.head()
# Out:
#    sum_axis_0_0  sum_axis_0_1  sum_axis_0_2  sum_axis_0_3  sum_axis_0_4  \
# 0           1.0           1.0          1.00          1.00          1.00
# 1           1.0           1.0          1.00          1.00          1.00
# 2           1.0           1.0          1.00          1.00          1.00
# 3           1.0           1.0          0.99          0.96          0.94
# 4           1.0           1.0          1.00          1.00          1.00
#
#    sum_axis_0_5  sum_axis_0_6  sum_axis_0_7  sum_axis_0_8  sum_axis_0_9  ...  \
# 0          1.00          1.00          1.00          1.00          1.00  ...
# 1          1.00          1.00          1.00          1.00          1.00  ...
# 2          1.00          1.00          1.00          1.00          1.00  ...
# 3          0.94          0.92          0.92          0.92          0.93  ...
# 4          1.00          1.00          1.00          1.00          1.00  ...
#
#    sum_axis_1_94  sum_axis_1_95  sum_axis_1_96  sum_axis_1_97  sum_axis_1_98  \
# 0        0.83871        0.83871       0.827957       0.817204       0.795699
# 1        1.00000        1.00000       1.000000       1.000000       1.000000
# 2        0.82000        0.90000       1.000000       1.000000       1.000000
# 3        0.96000        0.99000       1.000000       1.000000       1.000000
# 4        1.00000        0.99000       0.990000       0.990000       1.000000
#
#    sum_axis_1_99      mean  variance  outline_length        target
# 0       0.774194  0.744560  0.062088            9.82         other
# 1       1.000000  0.852347  0.021939            0.64         other
# 2       1.000000  0.478031  0.130620            6.68      limacina
# 3       1.000000  0.799294  0.037921            6.86  chaetognatha
# 4       1.000000  0.713423  0.065195           11.56       medusae
#
# [5 rows x 204 columns]

# %% [markdown]
# Some statistics about the features.

# %%
data.describe()
# Out:
#        sum_axis_0_0  sum_axis_0_1  sum_axis_0_2  sum_axis_0_3  sum_axis_0_4  \
# count  10752.000000  10752.000000  10752.000000  10752.000000  10752.000000
# mean       0.979279      0.977036      0.972997      0.965795      0.956058
# std        0.096922      0.098681      0.099546      0.102380      0.106950
# min        0.100000      0.050000      0.070000      0.030000      0.040000
# 25%        1.000000      1.000000      1.000000      0.990000      0.960000
# 50%        1.000000      1.000000      1.000000      1.000000      1.000000
# 75%        1.000000      1.000000      1.000000      1.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        sum_axis_0_5  sum_axis_0_6  sum_axis_0_7  sum_axis_0_8  sum_axis_0_9  \
# count  10752.000000  10752.000000  10752.000000  10752.000000  10752.000000
# mean       0.946609      0.938161      0.930047      0.922546      0.914766
# std        0.113165      0.119380      0.126461      0.132001      0.138568
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.940000      0.930000      0.916667      0.900000      0.880000
# 50%        1.000000      1.000000      1.000000      1.000000      1.000000
# 75%        1.000000      1.000000      1.000000      1.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        ...  sum_axis_1_93  sum_axis_1_94  sum_axis_1_95  sum_axis_1_96  \
# count  ...   10752.000000   10752.000000   10752.000000   10752.000000
# mean   ...       0.936903       0.943581       0.951833       0.961342
# std    ...       0.118902       0.114981       0.110555       0.106497
# min    ...       0.000000       0.000000       0.000000       0.000000
# 25%    ...       0.920000       0.940000       0.950000       0.980000
# 50%    ...       1.000000       1.000000       1.000000       1.000000
# 75%    ...       1.000000       1.000000       1.000000       1.000000
# max    ...       1.000000       1.000000       1.000000       1.000000
#
#        sum_axis_1_97  sum_axis_1_98  sum_axis_1_99          mean  \
# count   10752.000000   10752.000000   10752.000000  10752.000000
# mean        0.966297       0.970557       0.971949      0.677502
# std         0.105424       0.104636       0.105878      0.133997
# min         0.000000       0.010000       0.040000      0.209394
# 25%         1.000000       1.000000       1.000000      0.582888
# 50%         1.000000       1.000000       1.000000      0.694925
# 75%         1.000000       1.000000       1.000000      0.782364
# max         1.000000       1.000000       1.000000      0.969234
#
#            variance  outline_length
# count  10752.000000    10752.000000
# mean       0.074303        8.117898
# std        0.033898        4.244094
# min        0.001928        0.000000
# 25%        0.049183        5.740000
# 50%        0.068188        6.720000
# 75%        0.094579        9.102500
# max        0.214556       31.030000
#
# [8 rows x 203 columns]

# %%
data[['sum_axis_0_50','sum_axis_1_50','mean','variance', 'outline_length']].hist(figsize=(10, 10), bins=50, layout=(3, 2));

# %%
from sklearn import preprocessing
data_target = data.copy()
le = preprocessing.LabelEncoder()
data_target.target = le.fit_transform(data_target.target.values)
fig = plt.figure(figsize=(15,8))
sns.heatmap(data_target[['sum_axis_0_50','sum_axis_1_50','mean','variance','outline_length','target']].corr(), annot = True)
plt.title('Correlation_matrix')
plt.show()

# %%
sns.pairplot(data,hue='target',vars=['sum_axis_0_50','sum_axis_1_50','mean','variance','outline_length'])
plt.show()

# %% [markdown]
# <div style="background:#FFFFAA">
# <h1>Step 2: Building a predictive model</h1>
# </div>

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Loading data with DataManager</h2>
#     <p>
# We reload the data with the AutoML DataManager class because this is more convenient:
# </div>

# %%
from data_manager import DataManager
D = DataManager(data_name, data_dir, replace_missing=True)
print(D)
# Out:
# Info file found : /Users/Alan/Desktop/L2 - Info/ECOLO1/starting_kit/public_data/plankton_public.info
# DataManager : plankton
# info:
# 	usage = Sample dataset plankton data
# 	name = plankton
# 	task = multiclass.classification
# 	target_type = Numerical
# 	feat_type = Numerical
# 	metric = bac_metric
# 	time_budget = 1200
# 	feat_num = 202
# 	target_num = 7
# 	label_num = 7
# 	train_num = 10752
# 	valid_num = 3584
# 	test_num = 3584
# 	has_categorical = 0
# 	has_missing = 0
# 	is_sparse = 0
# 	format = dense
# data:
# 	X_train = array(10752, 203)
# 	Y_train = array(10752, 1)
# 	X_valid = array(3584, 203)
# 	Y_valid = array(0,)
# 	X_test = array(3584, 203)
# 	Y_test = array(0,)
# feat_type:	array(202,)
# feat_idx:	array(0,)

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Training a predictive model</h2>
#     <p>
# We provide an example of predictive model (for classification or regression) in the `sample_code_submission/` directory. It is a quite stupid model: it makes constant predictions. Replace it with your own model.
#     </div>

# %%
from data_io import write
from model import model
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.tree import DecisionTreeClassifier
from libscores import get_metric

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2> Feature selection </h2>
# </div>

# %%
def find_best_features ():
    scores=[]
    for i in range(1, 200, 1):
        M = model(classifier=DecisionTreeClassifier(max_depth=10, max_features = 'sqrt',random_state=42))
        feature_selection = SelectKBest(chi2, k=i) #after few tests, 170 look like the best sample
        feature_selection.fit(D.data['X_train'], D.data['Y_train'])
        X_train = feature_selection.transform(D.data['X_train'])
        X_valid = feature_selection.transform(D.data['X_valid']) 
        X_test = feature_selection.transform(D.data['X_test'])
        Y_train = D.data['Y_train']
        M.fit(X_train, Y_train)
        Y_hat_train = M.predict(X_train)
        metric_name,scoring_function=get_metric()
        scores.append(scoring_function(Y_train, Y_hat_train))
    return scores

scores = find_best_features()
plt.plot(scores)
print(max(scores), scores.index(max(scores)))
print(scores)

feature_selection = SelectKBest(chi2, k=scores.index(max(scores)))
feature_selection.fit(D.data['X_train'], D.data['Y_train'])

#apply this feature_selection to the data
D.data['X_train'] = feature_selection.transform(D.data['X_train'])
D.data['X_valid'] = feature_selection.transform(D.data['X_valid'])
D.data['X_test'] = feature_selection.transform(D.data['X_test'])
# Out:
# FIT: dim(X)= [10752, 1]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 1]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 2]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 2]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 3]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 3]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 4]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 4]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 5]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 5]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 6]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 6]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 7]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 7]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 8]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 8]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 9]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 9]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 10]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 10]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 11]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 11]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 12]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 12]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 13]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 13]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 14]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 14]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 15]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 15]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 16]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 16]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 17]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 17]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 18]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 18]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 19]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 19]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 20]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 20]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 21]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 21]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 22]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 22]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 23]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 23]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 24]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 24]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 25]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 25]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 26]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 26]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 27]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 27]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 28]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 28]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 29]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 29]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 30]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 30]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 31]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 31]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 32]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 32]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 33]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 33]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 34]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 34]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 35]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 35]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 36]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 36]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 37]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 37]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 38]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 38]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 39]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 39]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 40]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 40]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 41]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 41]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 42]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 42]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 43]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 43]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 44]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 44]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 45]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 45]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 46]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 46]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 47]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 47]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 48]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 48]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 49]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 49]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 50]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 50]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 51]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 51]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 52]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 52]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 53]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 53]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 54]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 54]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 55]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 55]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 56]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 56]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 57]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 57]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 58]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 58]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 59]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 59]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 60]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 60]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 61]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 61]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 62]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 62]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 63]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 63]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 64]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 64]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 65]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 65]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 66]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 66]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 67]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 67]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 68]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 68]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 69]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 69]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 70]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 70]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 71]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 71]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 72]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 72]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 73]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 73]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 74]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 74]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 75]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 75]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 76]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 76]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 77]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 77]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 78]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 78]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 79]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 79]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 80]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 80]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 81]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 81]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 82]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 82]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 83]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 83]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 84]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 84]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 85]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 85]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 86]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 86]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 87]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 87]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 88]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 88]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 89]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 89]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 90]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 90]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 91]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 91]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 92]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 92]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 93]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 93]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 94]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 94]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 95]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 95]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 96]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 96]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 97]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 97]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 98]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 98]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 99]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 99]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 100]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 100]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 101]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 101]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 102]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 102]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 103]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 103]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 104]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 104]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 105]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 105]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 106]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 106]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 107]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 107]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 108]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 108]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 109]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 109]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 110]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 110]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 111]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 111]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 112]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 112]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 113]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 113]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 114]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 114]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 115]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 115]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 116]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 116]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 117]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 117]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 118]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 118]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 119]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 119]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 120]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 120]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 121]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 121]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 122]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 122]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 123]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 123]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 124]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 124]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 125]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 125]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 126]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 126]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 127]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 127]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 128]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 128]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752, 129]
# FIT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [10752, 129]
# PREDICT: dim(y)= [10752, 1]
# FIT: dim(X)= [10752,
0.6413690476190476, 0.6567150297619048, 0.6574590773809523, 0.6508556547619048, 0.6377418154761906, 0.6302083333333333, 0.6607142857142857, 0.6182105654761905, 0.6486235119047619, 0.6536458333333334, 0.6428571428571429, 0.6587611607142857, 0.64453125, 0.6594122023809524, 0.6488095238095238, 0.6420200892857143, 0.6342075892857143, 0.650204613095238, 0.6513206845238095, 0.6497395833333333, 0.6522507440476192, 0.6529017857142857, 0.6640625000000001, 0.6497395833333333, 0.6584821428571429, 0.6573660714285714, 0.6476934523809524, 0.6566220238095237, 0.66015625, 0.6459263392857143, 0.6666666666666667, 0.6645275297619048, 0.6528087797619048, 0.654296875, 0.6375558035714286, 0.6497395833333333, 0.6520647321428571, 0.662202380952381, 0.6651785714285714, 0.6534598214285715, 0.6568080357142856, 0.6776413690476192, 0.6622023809523808, 0.6409040178571429, 0.6589471726190476, 0.6577380952380952, 0.6617373511904762, 0.6608072916666667, 0.6744791666666666, 0.6637834821428573, 0.6774553571428571, 0.6774553571428571, 0.6751302083333333, 0.6748511904761906, 0.6633184523809523, 0.6665736607142857, 0.6594122023809524, 0.671968005952381, 0.6576450892857143, 0.6692708333333333, 0.654296875, 0.6612723214285714, 0.6701078869047619, 0.6633184523809524, 0.6578311011904762, 0.6707589285714287, 0.6611793154761906, 0.679873511904762, 0.6763392857142857, 0.6707589285714286, 0.6879650297619048, 0.672061011904762, 0.6840587797619048, 0.6636904761904762, 0.6853608630952381, 0.6697358630952381, 0.670014880952381, 0.6872209821428571, 0.7077752976190476, 0.6652715773809524, 0.6649925595238094, 0.6687127976190477, 0.6790364583333333, 0.6555989583333333, 0.6846168154761905, 0.6781063988095237, 0.677455357142857, 0.6832217261904762, 0.6657366071428571, 0.6725260416666667, 0.6808035714285714, 0.6712239583333333, 0.6871279761904762, 0.6713169642857144, 0.69140625, 0.6837797619047619, 0.6804315476190476, 0.6814546130952381, 0.6643415178571429, 0.6962425595238095, 0.6937313988095238, 0.6844308035714286, 0.6483444940476192]

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2> Outliers detection et deletion </h2>
# </div>

# %%
rng = np.random.RandomState(42)

clf = IsolationForest(max_samples=10000, random_state=rng)#IsolationForest is a choice
clf.fit(D.data['X_train'])

y_pred_train = clf.predict(D.data['X_train'])

def countOutliers(y):
    counter = 0
    for i in y:
        if i < 0:
            counter += 1
    print(counter/len(y)*100, "%")

def removeOutliers(y, data):
    return data[y>0]

    
print(y_pred_train)

countOutliers(y_pred_train)
print(len(D.data['X_train']))
D.data['X_train'] = removeOutliers(y_pred_train, D.data['X_train'])
print(len(D.data['X_train']))
D.data['Y_train'] = removeOutliers(y_pred_train, D.data['Y_train'])
# Out:
# [1 1 1 ... 1 1 1]
# 3.869047619047619 %
# 10752
# 10336

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2> Application of dimension reduction (PCA) method </h2>
# </div>

# %%
def find_best_pca ():
    scores=[]
    for i in range(1, 170, 1):
        M = model(classifier=DecisionTreeClassifier(max_depth=10, max_features = 'sqrt',random_state=42
.5201896052028789, 0.5401448445171437, 0.5345900325339522, 0.5414454248346502, 0.5181019922904823, 0.5880736013673012, 0.5603479856354749, 0.5292943334552334, 0.572131065529186, 0.5008434867995553, 0.48606088776377765, 0.5265026088442897, 0.5402046570846112, 0.5626341678769241, 0.5059527927747088, 0.5367688010014079, 0.5348460736038316, 0.5243866228522501, 0.5092532380790443, 0.5169491305269366]

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2> Visualization of the outliers and training </h2>
# </div>

# %%
#Visualization of the outliers
sns.scatterplot(x="sum_axis_1_50", y="variance", data=data, hue=y_pred_train)

plt.plot()

# Decision tree model
M = model(classifier=DecisionTreeClassifier(max_depth=10, max_features = 'sqrt',random_state=42))

trained_model_name = model_dir + data_name

X_train = D.data['X_train']
Y_train = D.data['Y_train']

if not(M.is_trained):
    M.fit(X_train, Y_train)
    print('training')

Y_hat_train = M.predict(X_train) # Optional, not really needed to test on training examples
Y_hat_valid = M.predict(D.data['X_valid'])
Y_hat_test = M.predict(D.data['X_test'])
# Out:
# FIT: dim(X)= [10336, 10]
# FIT: dim(y)= [10336, 1]
# training
# PREDICT: dim(X)= [10336, 10]
# PREDICT: dim(y)= [10336, 1]
# PREDICT: dim(X)= [3584, 10]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 10]
# PREDICT: dim(y)= [3584, 1]

# %% [markdown]
# <div style="background:#FFFFAA">
#     <b> Save the trained model </b> (will be ready to reload next time around) and save the prediction results. IMPORTANT: if you save the trained model, it will be bundled with your sample code submission. Therefore your model will NOT be retrained on the challenge platform. Remove the pickle from the submission if you want the model to be retrained on the platform.
# </div>

# %%
M.save(trained_model_name)                 
result_name = result_dir + data_name
from data_io import write
write(result_name + '_train.predict', Y_hat_train)
write(result_name + '_valid.predict', Y_hat_valid)
write(result_name + '_test.predict', Y_hat_test)
# !ls $result_name*
# Out:
# sample_result_submission/plankton_test.predict
# sample_result_submission/plankton_train.predict
# sample_result_submission/plankton_valid.predict

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Scoring the results</h2>
#     <h3>Load the challenge metric</h3>
#     <p>
# <b>The metric chosen for your challenge</b> is identified in the "metric.txt" file found in the `scoring_function/` directory. The function "get_metric" searches first for a metric having that name in my_metric.py, then in libscores.py, then in sklearn.metric.
#     </div>

# %% [markdown]
# <div style="background:#FFFFAA">
# The chosen metric is the balanced accuracy. It computes the proportion of elements correctly predicted for each class. It then returns the mean of these values. The advantage of this metric is that every class is given an equal weight. <br> In our case, since all the classes are perfectly balanced, it is equivalent to simply computing the accuracy score but it the case the test set is changed and is no longer balanced, the balanced accuracy will still work properly while the accuracy score will not.
# </div>

# %%
from libscores import get_metric
metric_name, scoring_function = get_metric()
print('Using scoring metric:', metric_name)
# Uncomment the next line to display the code of the scoring metric
#??scoring_function
# Out:
# Using scoring metric: balanced_accuracy_score

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h3> Training performance </h3>
#     <p>
# The participants normally posess target values (labels) only for training examples (except for the sample data). We compute with the `example` metric the training score, which should be zero for perfect predictions.
#         </div>

# %%
print('Training score for the', metric_name, 'metric = %5.4f' % scoring_function(Y_train, Y_hat_train))
print('Ideal score for the', metric_name, 'metric = %5.4f' % scoring_function(Y_train, Y_train))
# Out:
# Training score for the balanced_accuracy_score metric = 0.6551
# Ideal score for the balanced_accuracy_score metric = 1.0000

# %% [markdown]
# You can add here other scores and result visualization.

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('default')
labels = ["chaetognatha","copepoda","euphausiids","fish_larvae","limacina","medusae","other"]
cm = confusion_matrix(Y_train, Y_hat_train)
cm = cm.astype('float') / cm.sum(axis=1)[:,np.newaxis]
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(cm, interpolation='nearest',cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
ax.set(xticks=np.arange(cm.shape[1]),yticks=np.arange(cm.shape[0]),xticklabels=labels,yticklabels=labels,title="Confusion matrix",xlabel="Predicted label",ylabel="True label")
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
fmt = '.2f'
thresh = cm.max()/2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")
fig.tight_layout()

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h3>Cross-validation performance</h3>
#     <p>
# The participants do not have access to the labels Y_valid and Y_test to self-assess their validation and test performances. But training performance is not a good prediction of validation or test performance. Using cross-validation, the training data is split into multiple training/test folds, which allows participants to self-assess their model during development. The average CV result and 95% confidence interval is displayed.
#    </div>

# %%
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
scores = cross_val_score(M, X_train, Y_train, cv=5, scoring=make_scorer(scoring_function))
print('\nCV score (95 perc. CI): %0.2f (+/- %0.2f)' % (scores.mean(), scores.std() * 2))
# Out:
# FIT: dim(X)= [8268, 10]
# FIT: dim(y)= [8268, 1]
# PREDICT: dim(X)= [2068, 10]
# PREDICT: dim(y)= [2068, 1]
# FIT: dim(X)= [8269, 10]
# FIT: dim(y)= [8269, 1]
# PREDICT: dim(X)= [2067, 10]
# PREDICT: dim(y)= [2067, 1]
# FIT: dim(X)= [8269, 10]
# FIT: dim(y)= [8269, 1]
# PREDICT: dim(X)= [2067, 10]
# PREDICT: dim(y)= [2067, 1]
# FIT: dim(X)= [8269, 10]
# FIT: dim(y)= [8269, 1]
# PREDICT: dim(X)= [2067, 10]
# PREDICT: dim(y)= [2067, 1]
# FIT: dim(X)= [8269, 10]
# FIT: dim(y)= [8269, 1]
# PREDICT: dim(X)= [2067, 10]
# PREDICT: dim(y)= [2067, 1]
#
# CV score (95 perc. CI): 0.55 (+/- 0.03)

# %% [markdown]
# <div style="background:#FFFFAA">
# <h1> Step 3: Making a submission </h1>
#
# <h2> Unit testing </h2>
#
# It is <b><span style="color:red">important that you test your submission files before submitting them</span></b>. All you have to do to make a submission is modify the file <code>model.py</code> in the <code>sample_code_submission/</code> directory, then run this test to make sure everything works fine. This is the actual program that will be run on the server to test your submission.
# <br>
# Keep the sample code simple.
# </div>

# %%
# !source activate python3; python $problem_dir/ingestion.py $data_dir $result_dir $problem_dir $model_dir
# Out:
# /bin/sh: activate: No such file or directory

# %% [markdown]
# <div style="background:#FFFFAA">
# Also test the scoring program:
#     </div>

# %%
scoring_output_dir = 'scoring_output'
# !source activate python3; python $score_dir/score.py $data_dir $result_dir $scoring_output_dir
# Out:
# /bin/sh: activate: No such file or directory

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h1> Preparing the submission </h1>
#
# Zip the contents of `sample_code_submission/` (without the directory), or download the challenge public_data and run the command in the previous cell, after replacing sample_data by public_data.
# Then zip the contents of `sample_result_submission/` (without the directory).
# <b><span style="color:red">Do NOT zip the data with your submissions</span></b>.

# %%
import datetime 
from data_io import zipdir
the_date = datetime.datetime.now().strftime("%y-%m-%d-%H-%M")
sample_code_submission = './sample_code_submission_' + the_date + '.zip'
sample_result_submission = './sample_result_submission_' + the_date + '.zip'
zipdir(sample_code_submission, model_dir)
zipdir(sample_result_submission, result_dir)
print("Submit one of these files:\n" + sample_code_submission + "\n" + sample_result_submission)
# Out:
# Submit one of these files:
# ./sample_code_submission_20-03-15-21-35.zip
# ./sample_result_submission_20-03-15-21-35.zip

# %%
import sklearn
print("Sklearn: ", sklearn.__version__)
print("Seaborn: ", sns.__version__)
print("Numpy: ", np.__version__)
print("Panda: ", pd.__version__)
# Out:
# Sklearn:  0.22.1
# Seaborn:  0.10.0
# Numpy:  1.18.1
# Panda:  1.0.1
